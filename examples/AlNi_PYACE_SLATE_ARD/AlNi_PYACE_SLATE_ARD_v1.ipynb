# %% [markdown]
# # SLATE ARD Validation Report
# /scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/AlNi_PYACE_SLATE_ARD

# %% [markdown]
# ## Configuration

# %%
import json

# Configuration from FitSNAP run
config = {
  "PYACE": {
    "name": "PYACE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": null,
    "elements": ["Al","Ni"],
    "numtypes": 2,
    "types": ["Al","Ni"],
    "cutoff": 10.0,
    "delta_spline_bins": 0.001,
    "bikflag": 0,
    "bzeroflag": 0,
    "dgradflag": 0,
    "erefs": ["0.0","0.0"],
    "type_mapping": {
      "Al": 1,
      "Ni": 2
    },
    "embeddings": {
      "Al": {
        "npot": "FinnisSinclair",
        "fs_parameters": [1,1],
        "ndensity": 1
      },
      "Ni": {
        "npot": "FinnisSinclair",
        "fs_parameters": [1,1],
        "ndensity": 1
      }
    },
    "functions": {
      "ALL": {
        "lmin_by_orders": [0,0,0],
        "lmax_by_orders": [0,3,3],
        "nradmax_by_orders": [5,2,1]
      }
    },
    "nradmax": 5,
    "lmax": 3,
    "bonds": {
      "AlAl": {
        "radbase": "ChebExpCos",
        "radparameters": [0.342],
        "rcut": 6.832,
        "dcut": 0.01,
        "core-repulsion": [0,0.342],
        "r_in": 0.625,
        "delta_in": 0.01,
        "nradmax": 5,
        "nradbasemax": 5,
        "lmax": 3
      },
      "AlNi": {
        "radbase": "ChebExpCos",
        "radparameters": [0.318],
        "rcut": 6.356,
        "dcut": 0.01,
        "core-repulsion": [0,0.318],
        "r_in": 0.65,
        "delta_in": 0.01,
        "nradmax": 5,
        "nradbasemax": 5,
        "lmax": 3
      },
      "NiAl": {
        "radbase": "ChebExpCos",
        "radparameters": [0.318],
        "rcut": 6.356,
        "dcut": 0.01,
        "core-repulsion": [0,0.318],
        "r_in": 0.65,
        "delta_in": 0.01,
        "nradmax": 5,
        "nradbasemax": 5,
        "lmax": 3
      },
      "NiNi": {
        "radbase": "ChebExpCos",
        "radparameters": [0.281],
        "rcut": 5.61,
        "dcut": 0.01,
        "core-repulsion": [0,0.281],
        "r_in": 0.54,
        "delta_in": 0.01,
        "nradmax": 5,
        "nradbasemax": 5,
        "lmax": 3
      }
    },
    "rcutfac": [6.832,6.356,6.356,5.61],
    "ace_config": {
      "cutoff": 10.0,
      "deltaSplineBins": 0.001,
      "elements": ["Al","Ni"],
      "embeddings": {
        "Al": {
          "npot": "FinnisSinclair",
          "fs_parameters": [1,1],
          "ndensity": 1
        },
        "Ni": {
          "npot": "FinnisSinclair",
          "fs_parameters": [1,1],
          "ndensity": 1
        }
      },
      "bonds": {
        "AlAl": {
          "radbase": "ChebExpCos",
          "radparameters": [0.342],
          "rcut": 6.832,
          "dcut": 0.01,
          "core-repulsion": [0,0.342],
          "r_in": 0.625,
          "delta_in": 0.01,
          "nradmax": 5,
          "nradbasemax": 5,
          "lmax": 3
        },
        "AlNi": {
          "radbase": "ChebExpCos",
          "radparameters": [0.318],
          "rcut": 6.356,
          "dcut": 0.01,
          "core-repulsion": [0,0.318],
          "r_in": 0.65,
          "delta_in": 0.01,
          "nradmax": 5,
          "nradbasemax": 5,
          "lmax": 3
        },
        "NiAl": {
          "radbase": "ChebExpCos",
          "radparameters": [0.318],
          "rcut": 6.356,
          "dcut": 0.01,
          "core-repulsion": [0,0.318],
          "r_in": 0.65,
          "delta_in": 0.01,
          "nradmax": 5,
          "nradbasemax": 5,
          "lmax": 3
        },
        "NiNi": {
          "radbase": "ChebExpCos",
          "radparameters": [0.281],
          "rcut": 5.61,
          "dcut": 0.01,
          "core-repulsion": [0,0.281],
          "r_in": 0.54,
          "delta_in": 0.01,
          "nradmax": 5,
          "nradbasemax": 5,
          "lmax": 3
        }
      },
      "functions": {
        "ALL": {
          "lmin_by_orders": [0,0,0],
          "lmax_by_orders": [0,3,3],
          "nradmax_by_orders": [5,2,1]
        }
      }
    },
    "ctilde_basis": "<pyace.basis.ACECTildeBasisSet object at 0x14f5768d19f0>",
    "ncoeff": 192,
    "blist": ["Al [0]","Ni [0]","Al Al ns [1] ls [0]","Al Al ns [2] ls [0]","Al Al ns [3] ls [0]","Al Al ns [4] ls [0]","Al Al ns [5] ls [0]","Al Ni ns [1] ls [0]","Al Ni ns [2] ls [0]","Al Ni ns [3] ls [0]","Al Ni ns [4] ls [0]","Al Ni ns [5] ls [0]","Ni Al ns [1] ls [0]","Ni Al ns [2] ls [0]","Ni Al ns [3] ls [0]","Ni Al ns [4] ls [0]","Ni Al ns [5] ls [0]","Ni Ni ns [1] ls [0]","Ni Ni ns [2] ls [0]","Ni Ni ns [3] ls [0]","Ni Ni ns [4] ls [0]","Ni Ni ns [5] ls [0]","Al Al Al ns [1,1] ls [0,0]","Al Al Al ns [1,1] ls [1,1]","Al Al Al ns [1,1] ls [2,2]","Al Al Al ns [1,1] ls [3,3]","Al Al Al ns [1,2] ls [0,0]","Al Al Al ns [1,2] ls [1,1]","Al Al Al ns [1,2] ls [2,2]","Al Al Al ns [1,2] ls [3,3]","Al Al Al ns [2,2] ls [0,0]","Al Al Al ns [2,2] ls [1,1]","Al Al Al ns [2,2] ls [2,2]","Al Al Al ns [2,2] ls [3,3]","Al Al Ni ns [1,1] ls [0,0]","Al Al Ni ns [1,1] ls [1,1]","Al Al Ni ns [1,1] ls [2,2]","Al Al Ni ns [1,1] ls [3,3]","Al Al Ni ns [1,2] ls [0,0]","Al Al Ni ns [1,2] ls [1,1]","Al Al Ni ns [1,2] ls [2,2]","Al Al Ni ns [1,2] ls [3,3]","Al Al Ni ns [2,1] ls [0,0]","Al Al Ni ns [2,1] ls [1,1]","Al Al Ni ns [2,1] ls [2,2]","Al Al Ni ns [2,1] ls [3,3]","Al Al Ni ns [2,2] ls [0,0]","Al Al Ni ns [2,2] ls [1,1]","Al Al Ni ns [2,2] ls [2,2]","Al Al Ni ns [2,2] ls [3,3]","Al Ni Ni ns [1,1] ls [0,0]","Al Ni Ni ns [1,1] ls [1,1]","Al Ni Ni ns [1,1] ls [2,2]","Al Ni Ni ns [1,1] ls [3,3]","Al Ni Ni ns [1,2] ls [0,0]","Al Ni Ni ns [1,2] ls [1,1]","Al Ni Ni ns [1,2] ls [2,2]","Al Ni Ni ns [1,2] ls [3,3]","Al Ni Ni ns [2,2] ls [0,0]","Al Ni Ni ns [2,2] ls [1,1]","Al Ni Ni ns [2,2] ls [2,2]","Al Ni Ni ns [2,2] ls [3,3]","Al Al Al Al ns [1,1,1] ls [0,0,0]","Al Al Al Al ns [1,1,1] ls [0,1,1]","Al Al Al Al ns [1,1,1] ls [0,2,2]","Al Al Al Al ns [1,1,1] ls [0,3,3]","Al Al Al Al ns [1,1,1] ls [1,1,2]","Al Al Al Al ns [1,1,1] ls [1,2,3]","Al Al Al Al ns [1,1,1] ls [2,2,2]","Al Al Al Al ns [1,1,1] ls [2,3,3]","Al Al Al Ni ns [1,1,1] ls [0,0,0]","Al Al Al Ni ns [1,1,1] ls [0,1,1]","Al Al Al Ni ns [1,1,1] ls [0,2,2]","Al Al Al Ni ns [1,1,1] ls [0,3,3]","Al Al Al Ni ns [1,1,1] ls [1,1,0]","Al Al Al Ni ns [1,1,1] ls [1,1,2]","Al Al Al Ni ns [1,1,1] ls [1,2,1]","Al Al Al Ni ns [1,1,1] ls [1,2,3]","Al Al Al Ni ns [1,1,1] ls [1,3,2]","Al Al Al Ni ns [1,1,1] ls [2,2,0]","Al Al Al Ni ns [1,1,1] ls [2,2,2]","Al Al Al Ni ns [1,1,1] ls [2,3,1]","Al Al Al Ni ns [1,1,1] ls [2,3,3]","Al Al Al Ni ns [1,1,1] ls [3,3,0]","Al Al Al Ni ns [1,1,1] ls [3,3,2]","Al Al Ni Ni ns [1,1,1] ls [0,0,0]","Al Al Ni Ni ns [1,1,1] ls [0,1,1]","Al Al Ni Ni ns [1,1,1] ls [0,2,2]","Al Al Ni Ni ns [1,1,1] ls [0,3,3]","Al Al Ni Ni ns [1,1,1] ls [1,0,1]","Al Al Ni Ni ns [1,1,1] ls [1,1,2]","Al Al Ni Ni ns [1,1,1] ls [1,2,3]","Al Al Ni Ni ns [1,1,1] ls [2,0,2]","Al Al Ni Ni ns [1,1,1] ls [2,1,1]","Al Al Ni Ni ns [1,1,1] ls [2,1,3]","Al Al Ni Ni ns [1,1,1] ls [2,2,2]","Al Al Ni Ni ns [1,1,1] ls [2,3,3]","Al Al Ni Ni ns [1,1,1] ls [3,0,3]","Al Al Ni Ni ns [1,1,1] ls [3,1,2]","Al Al Ni Ni ns [1,1,1] ls [3,2,3]","Al Ni Ni Ni ns [1,1,1] ls [0,0,0]","Al Ni Ni Ni ns [1,1,1] ls [0,1,1]","Al Ni Ni Ni ns [1,1,1] ls [0,2,2]","Al Ni Ni Ni ns [1,1,1] ls [0,3,3]","Al Ni Ni Ni ns [1,1,1] ls [1,1,2]","Al Ni Ni Ni ns [1,1,1] ls [1,2,3]","Al Ni Ni Ni ns [1,1,1] ls [2,2,2]","Al Ni Ni Ni ns [1,1,1] ls [2,3,3]","Ni Al Al ns [1,1] ls [0,0]","Ni Al Al ns [1,1] ls [1,1]","Ni Al Al ns [1,1] ls [2,2]","Ni Al Al ns [1,1] ls [3,3]","Ni Al Al ns [1,2] ls [0,0]","Ni Al Al ns [1,2] ls [1,1]","Ni Al Al ns [1,2] ls [2,2]","Ni Al Al ns [1,2] ls [3,3]","Ni Al Al ns [2,2] ls [0,0]","Ni Al Al ns [2,2] ls [1,1]","Ni Al Al ns [2,2] ls [2,2]","Ni Al Al ns [2,2] ls [3,3]","Ni Al Ni ns [1,1] ls [0,0]","Ni Al Ni ns [1,1] ls [1,1]","Ni Al Ni ns [1,1] ls [2,2]","Ni Al Ni ns [1,1] ls [3,3]","Ni Al Ni ns [1,2] ls [0,0]","Ni Al Ni ns [1,2] ls [1,1]","Ni Al Ni ns [1,2] ls [2,2]","Ni Al Ni ns [1,2] ls [3,3]","Ni Al Ni ns [2,1] ls [0,0]","Ni Al Ni ns [2,1] ls [1,1]","Ni Al Ni ns [2,1] ls [2,2]","Ni Al Ni ns [2,1] ls [3,3]","Ni Al Ni ns [2,2] ls [0,0]","Ni Al Ni ns [2,2] ls [1,1]","Ni Al Ni ns [2,2] ls [2,2]","Ni Al Ni ns [2,2] ls [3,3]","Ni Ni Ni ns [1,1] ls [0,0]","Ni Ni Ni ns [1,1] ls [1,1]","Ni Ni Ni ns [1,1] ls [2,2]","Ni Ni Ni ns [1,1] ls [3,3]","Ni Ni Ni ns [1,2] ls [0,0]","Ni Ni Ni ns [1,2] ls [1,1]","Ni Ni Ni ns [1,2] ls [2,2]","Ni Ni Ni ns [1,2] ls [3,3]","Ni Ni Ni ns [2,2] ls [0,0]","Ni Ni Ni ns [2,2] ls [1,1]","Ni Ni Ni ns [2,2] ls [2,2]","Ni Ni Ni ns [2,2] ls [3,3]","Ni Al Al Al ns [1,1,1] ls [0,0,0]","Ni Al Al Al ns [1,1,1] ls [0,1,1]","Ni Al Al Al ns [1,1,1] ls [0,2,2]","Ni Al Al Al ns [1,1,1] ls [0,3,3]","Ni Al Al Al ns [1,1,1] ls [1,1,2]","Ni Al Al Al ns [1,1,1] ls [1,2,3]","Ni Al Al Al ns [1,1,1] ls [2,2,2]","Ni Al Al Al ns [1,1,1] ls [2,3,3]","Ni Al Al Ni ns [1,1,1] ls [0,0,0]","Ni Al Al Ni ns [1,1,1] ls [0,1,1]","Ni Al Al Ni ns [1,1,1] ls [0,2,2]","Ni Al Al Ni ns [1,1,1] ls [0,3,3]","Ni Al Al Ni ns [1,1,1] ls [1,1,0]","Ni Al Al Ni ns [1,1,1] ls [1,1,2]","Ni Al Al Ni ns [1,1,1] ls [1,2,1]","Ni Al Al Ni ns [1,1,1] ls [1,2,3]","Ni Al Al Ni ns [1,1,1] ls [1,3,2]","Ni Al Al Ni ns [1,1,1] ls [2,2,0]","Ni Al Al Ni ns [1,1,1] ls [2,2,2]","Ni Al Al Ni ns [1,1,1] ls [2,3,1]","Ni Al Al Ni ns [1,1,1] ls [2,3,3]","Ni Al Al Ni ns [1,1,1] ls [3,3,0]","Ni Al Al Ni ns [1,1,1] ls [3,3,2]","Ni Al Ni Ni ns [1,1,1] ls [0,0,0]","Ni Al Ni Ni ns [1,1,1] ls [0,1,1]","Ni Al Ni Ni ns [1,1,1] ls [0,2,2]","Ni Al Ni Ni ns [1,1,1] ls [0,3,3]","Ni Al Ni Ni ns [1,1,1] ls [1,0,1]","Ni Al Ni Ni ns [1,1,1] ls [1,1,2]","Ni Al Ni Ni ns [1,1,1] ls [1,2,3]","Ni Al Ni Ni ns [1,1,1] ls [2,0,2]","Ni Al Ni Ni ns [1,1,1] ls [2,1,1]","Ni Al Ni Ni ns [1,1,1] ls [2,1,3]","Ni Al Ni Ni ns [1,1,1] ls [2,2,2]","Ni Al Ni Ni ns [1,1,1] ls [2,3,3]","Ni Al Ni Ni ns [1,1,1] ls [3,0,3]","Ni Al Ni Ni ns [1,1,1] ls [3,1,2]","Ni Al Ni Ni ns [1,1,1] ls [3,2,3]","Ni Ni Ni Ni ns [1,1,1] ls [0,0,0]","Ni Ni Ni Ni ns [1,1,1] ls [0,1,1]","Ni Ni Ni Ni ns [1,1,1] ls [0,2,2]","Ni Ni Ni Ni ns [1,1,1] ls [0,3,3]","Ni Ni Ni Ni ns [1,1,1] ls [1,1,2]","Ni Ni Ni Ni ns [1,1,1] ls [1,2,3]","Ni Ni Ni Ni ns [1,1,1] ls [2,2,2]","Ni Ni Ni Ni ns [1,1,1] ls [2,3,3]"],
    "lambda_mask": "[ True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True]"
  },
  "CALCULATOR": {
    "name": "CALCULATOR",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["calculator","energy","per_atom_energy","force","stress","nonlinear","per_atom_scalar"],
    "calculator": "LAMMPSPYACE",
    "energy": 1,
    "per_atom_energy": 0,
    "per_atom_scalar": 0,
    "dee": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/detailed_energy_errors.dat",
    "force": 1,
    "dfe": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/detailed_force_errors.dat",
    "stress": 1,
    "dse": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/detailed_stress_errors.dat",
    "nonlinear": 0,
    "linear": true
  },
  "REFERENCE": {
    "name": "REFERENCE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["units","atom_style","pair_style","pair_coeff"],
    "units": "metal",
    "atom_style": "atomic",
    "lmp_pairdecl": ["pair_style hybrid/overlay zero 6.842222 zbl 4.782556 5.465778 zbl 4.448889 5.084444 zbl 3.927000 4.488000","pair_coeff * * zero","pair_coeff 1 1 zbl 113 13","pair_coeff 1 2 zbl 213 28","pair_coeff 2 2 zbl 328 28"]
  },
  "SOLVER": {
    "name": "SOLVER",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["solver","normalweight","normratio","compute_testerrs","detailed_errors","nsam","cov_nugget","mcmc_num","mcmc_gamma","mcmc_sigma","merr_mult","merr_method","merr_cfs"],
    "solver": "SLATE",
    "multinode": true,
    "normalweight": -12.0,
    "normratio": 0.5,
    "compute_testerrs": 1,
    "detailed_errors": 0,
    "nsam": 0,
    "cov_nugget": 0.0,
    "mcmc_num": 10000,
    "mcmc_gamma": 0.01,
    "mcmc_sigma": 0.1,
    "merr_mult": 0,
    "merr_method": "abc",
    "merr_cfs": "all"
  },
  "SLATE": {
    "name": "SLATE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["method","alpha","max_iter","tol","alphabig","alphasmall","lambdabig","lambdasmall","threshold_lambda","threshold_gamma","pruning_method","directmethod","scap","scai","logcut"],
    "method": "ARD",
    "alpha": 1e-08,
    "max_iter": 100,
    "tol": 0.001,
    "alphabig": 1e-12,
    "alphasmall": 1e-14,
    "lambdabig": 1e-06,
    "lambdasmall": 1e-06,
    "pruning_method": "gamma",
    "threshold_lambda": 0.0,
    "threshold_gamma": 0.01,
    "directmethod": 0,
    "scap": 0.001,
    "scai": 0.001,
    "logcut": 0.3
  },
  "SCRAPER": {
    "name": "SCRAPER",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["scraper","filename","save_group_scrape","read_group_scrape","property_array","max_configs_per_rank","require_energy","require_forces","verbose","data_id","charge","composition"],
    "scraper": "ADIOS2",
    "filename": "",
    "save_group_scrape": "None",
    "read_group_scrape": "None",
    "max_configs_per_rank": null,
    "require_energy": 1,
    "require_forces": null,
    "verbose": 0,
    "data_id": "None",
    "charge": "None",
    "composition": "None",
    "properties": {
      "Stress": ["pressure","Metal","Metal"],
      "Lattice": ["length","Metal","Metal"],
      "Energy": ["energy","Metal","Metal"],
      "Positions": ["length","Metal","Metal"],
      "Forces": ["force","Metal","Metal"]
    }
  },
  "PATH": {
    "name": "PATH",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["dataPath","groupFile"],
    "infile_directory": "",
    "outfile_directory": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD",
    "datapath": "omat24_AlNi.bp",
    "group_file": "grouplist.in"
  },
  "GROUPS": {
    "name": "GROUPS",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["group_sections","group_types","smartweights","random_sampling","random_seed","vasp_use_TOTEN","vasp_json_pathname","vasp_ignore_incomplete","vasp_ignore_jsons","vasp_unconverged_label","BOLTZ"],
    "group_sections": ["name","eweight","fweight","vweight"],
    "group_types": ["<class 'str'>","<class 'float'>","<class 'float'>","<class 'float'>","<class 'float'>","<class 'float'>"],
    "smartweights": 1,
    "random_sampling": 0,
    "random_seed": 0.0,
    "vasp_use_TOTEN": 0,
    "vasp_json_pathname": "vJSON",
    "vasp_ignore_incomplete": 1,
    "vasp_ignore_jsons": 0,
    "vasp_unconverged_label": "UNCONVERGED",
    "boltz": 0.0,
    "group_table": {
      "rattled-300": {
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 0.01,
        "training_size": 425,
        "testing_size": 13
      },
      "rattled-500": {
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 0.01,
        "training_size": 664,
        "testing_size": 9
      },
      "rattled-1000": {
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 0.01,
        "training_size": 968,
        "testing_size": 6
      },
      "rattled-relax": {
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 0.01,
        "training_size": 405,
        "testing_size": 14
      },
      "aimd-from-PBE-1000-npt": {
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 0.01,
        "training_size": 1397,
        "testing_size": 15
      },
      "aimd-from-PBE-1000-nvt": {
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 0.01,
        "training_size": 1114,
        "testing_size": 10
      },
      "aimd-from-PBE-3000-npt": {
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 0.01,
        "training_size": 545,
        "testing_size": 7
      },
      "aimd-from-PBE-3000-nvt": {
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 0.01,
        "training_size": 611,
        "testing_size": 1
      }
    }
  },
  "OUTFILE": {
    "name": "OUTFILE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["output_style","metrics","metrics_style","potential","detailed_errors","validation"],
    "metric_file": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/AlNi_PYACE_SLATE_ARD.md",
    "potential_name": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/AlNi_PYACE_SLATE_ARD",
    "validation": "1",
    "metrics": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/AlNi_PYACE_SLATE_ARD.md",
    "potential": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/AlNi_PYACE_SLATE_ARD",
    "output_style": "PACE",
    "metrics_style": "MD"
  },
  "EXTRAS": {
    "name": "EXTRAS",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["multinode_testing","apply_transpose","only_test","dump_descriptors","dump_truth","dump_weights","dump_dataframe","dump_peratom","dump_perconfig","dump_configs","debug"],
    "multinode_testing": 0,
    "apply_transpose": 0,
    "only_test": 0,
    "dump_a": 0,
    "dump_b": 0,
    "dump_w": 0,
    "dump_dataframe": 0,
    "dump_peratom": 0,
    "dump_perconfig": 0,
    "dump_configs": 0,
    "debug": 0,
    "descriptor_file": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/Descriptors.npy",
    "truth_file": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/Truth-Ref.npy",
    "weights_file": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/Weights.npy",
    "dataframe_file": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/FitSNAP.df",
    "peratom_file": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/peratom.dat",
    "perconfig_file": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/perconfig.dat",
    "configs_file": "/scratch/mmurp027/FitSNAP-alphataubio/examples/AlNi_PYACE_SLATE_ARD/configs.pickle"
  },
  "MEMORY": {
    "name": "MEMORY",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x14f8721916a0>",
    "infile": "AlNi_PYACE_SLATE_ARD.in",
    "allowedkeys": ["memory","override"],
    "mem_bytes": 811117662208,
    "memory": 811117662208,
    "override": 0
  }
}

# Display key settings
print('ARD Settings:')
for key in ['max_iter', 'tol', 'threshold_lambda', 'pruning_method']:
    if key in config.get('SLATE', {}): print(f'  {key}: {config["SLATE"][key]}')

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# ### Energy (eV)
#
# **Unweighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6129</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.125414</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.160343</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.996093</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">75</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.126124</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.155127</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995732</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">545</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.081886</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.101913</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997393</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">7</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.262544</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.265676</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.976103</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-relax</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">405</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.155221</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.214735</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.992655</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">14</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.135994</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.175282</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997842</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-500</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">664</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.141186</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.171668</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995529</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">9</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.122474</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.161319</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.993253</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-1000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">968</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.140467</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.181015</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995777</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.155466</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.159195</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.957867</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-300</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">425</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.106980</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.127947</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.996279</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">13</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.106240</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.120609</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.990602</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1397</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.132096</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.175861</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.994148</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.092874</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.120438</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995377</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1114</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.118467</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.139225</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.996747</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">10</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.089470</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.093524</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.883689</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">611</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.113701</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.129194</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997075</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.013555</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.013555</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>
#
#
# **Weighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6129</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.123751</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.158944</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.996055</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">75</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.122327</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.154376</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995729</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">545</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.081886</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.101913</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997393</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">7</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.262544</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.265676</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.976103</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-relax</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">405</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.155221</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.214735</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.992655</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">14</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.135994</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.175282</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997842</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-500</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">664</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.141186</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.171668</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995529</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">9</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.122474</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.161319</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.993253</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-1000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">968</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.140467</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.181015</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995777</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.155466</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.159195</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.957867</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-300</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">425</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.106980</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.127947</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.996279</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">13</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.106240</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.120609</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.990602</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1397</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.132096</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.175861</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.994148</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.092874</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.120438</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995377</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1114</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.118467</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.139225</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.996747</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">10</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.089470</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.093524</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.883689</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">611</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.113701</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.129194</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997075</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.013555</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.013555</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Force (eV/A)
#
# **Unweighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">435441</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.270670</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.575802</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.933373</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3846</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.275088</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.397057</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.979940</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-1000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">43077</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.421659</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.850491</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.960637</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">264</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.463992</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.751995</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.970035</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-300</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">18795</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.415602</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.821854</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.964709</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">552</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.362931</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.495948</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.986689</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-500</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">30516</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.400876</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">1.502410</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.839365</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">396</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.341553</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.479536</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.981761</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">114648</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.245240</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.315962</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.960407</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1320</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.255017</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.321160</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.945173</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">130272</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.246286</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.318940</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.927065</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">192</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.227748</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.292002</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.964006</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-relax</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">11775</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.180139</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.272449</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.958438</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">492</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.218089</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.276497</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.979846</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">31098</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.203157</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.267691</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.944208</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">180</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.196661</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.270606</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.948671</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">55260</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.199300</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.263411</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.930247</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">450</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.170786</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.244487</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.994611</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>
#
#
# **Weighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">435441</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.275729</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.517876</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.963628</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3846</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.274099</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.415670</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.978833</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-1000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">43077</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.401708</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.728164</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.970983</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">264</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.433505</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.710043</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.972787</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-300</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">18795</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.405916</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.750849</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.970756</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">552</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.359827</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.489273</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.987025</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-500</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">30516</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.372209</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.811046</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.949643</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">396</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.339600</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.474519</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.981935</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">114648</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.244507</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.315151</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.961945</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1320</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.255061</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.321701</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.945886</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">55260</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.184417</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.251729</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.955533</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">450</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.184752</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.296438</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.988082</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">130272</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.247048</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.320013</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.930978</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">192</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.227748</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.292002</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.964006</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">31098</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.192449</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.260672</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.947539</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">180</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.196661</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.270606</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.948671</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-relax</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">11775</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.157578</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.246422</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.961119</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">492</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.195641</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.252342</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.977095</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Stress (GPa)
#
# **Unweighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">36774</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.764394</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">27.272892</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.878470</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">450</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.192158</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">22.382639</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.919583</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-300</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">2550</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">25.143177</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">36.795136</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.831709</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">78</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">21.337553</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.878824</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.845350</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-1000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">5808</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">22.634369</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">35.098022</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.840464</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">36</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.716037</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.081633</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.819676</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-relax</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">2430</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">15.618350</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.306697</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.815595</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">84</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.247473</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">26.418686</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.925555</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-500</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3984</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">20.597549</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">31.844020</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.818705</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">54</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">15.998961</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">25.174042</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.801712</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3270</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.837809</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">27.212536</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.780733</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">42</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">12.314243</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.127932</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.892508</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">8382</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">13.484656</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">21.625146</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.928508</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">90</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">8.883884</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.073182</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.966706</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3666</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">15.549510</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">23.895615</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.836541</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">8.609034</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">11.627064</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.988922</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6684</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">10.853164</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.647204</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.948341</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">60</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">6.120518</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">7.759712</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.991614</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>
#
#
# **Weighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">36774</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.714823</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.565608</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.860139</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">450</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">13.653463</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">21.505301</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.931624</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-300</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">2550</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">25.143177</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">36.795136</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.831709</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">78</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">21.337553</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.878824</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.845350</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-1000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">5808</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">22.634369</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">35.098022</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.840464</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">36</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.716037</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.081633</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.819676</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-relax</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">2430</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">15.618350</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.306697</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.815595</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">84</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.247473</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">26.418686</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.925555</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;rattled-500</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3984</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">20.597549</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">31.844020</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.818705</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">54</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">15.998961</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">25.174042</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.801712</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3270</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.837809</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">27.212536</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.780733</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">42</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">12.314243</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.127932</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.892508</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-npt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">8382</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">13.484656</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">21.625146</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.928508</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">90</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">8.883884</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.073182</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.966706</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-3000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3666</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">15.549510</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">23.895615</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.836541</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">8.609034</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">11.627064</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.988922</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aimd-from-PBE-1000-nvt</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6684</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">10.853164</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.647204</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.948341</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">60</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">6.120518</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">7.759712</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.991614</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Gamma and Lambda Evolution Heatmaps

# %% [markdown]
# ## Gamma Heatmaps

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# ## Lambda Heatmaps

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# ## Summary Statistics
# <img src="data:image/svg+xml;base64,..." alt="Gamma Heatmap" style="width:100%;height:auto;">
