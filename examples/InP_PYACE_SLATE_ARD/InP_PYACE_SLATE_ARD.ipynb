# %% [markdown]
# # SLATE ARD Validation Report
# /Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/InP_PYACE_SLATE_ARD

# %% [markdown]
# ## Configuration

# %%
import json

# Configuration from FitSNAP run
config = {
  "PYACE": {
    "name": "PYACE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": null,
    "elements": ["In","P"],
    "numtypes": 2,
    "types": ["In","P"],
    "cutoff": 10.0,
    "delta_spline_bins": 0.001,
    "bikflag": 0,
    "bzeroflag": 1,
    "dgradflag": 0,
    "erefs": ["0.0","0.0"],
    "type_mapping": {
      "In": 1,
      "P": 2
    },
    "embeddings": {
      "In": {
        "npot": "FinnisSinclair",
        "fs_parameters": [1,1],
        "ndensity": 1
      },
      "P": {
        "npot": "FinnisSinclair",
        "fs_parameters": [1,1],
        "ndensity": 1
      }
    },
    "functions": {
      "ALL": {
        "nmax_by_rank": [22,3,2,1],
        "lmin_by_rank": [0,0,1,1],
        "lmax_by_rank": [1,2,2,1]
      }
    },
    "bonds": {
      "InIn": {
        "radbase": "ChebExpCos",
        "radparameters": [1.737],
        "rcut": 5.79,
        "dcut": 0.01,
        "core-repulsion": [0,1.737],
        "rcut_in": 1.705,
        "dcut_in": 0.01
      },
      "PIn": {
        "radbase": "ChebExpCos",
        "radparameters": [1.502],
        "rcut": 5.007,
        "dcut": 0.01,
        "core-repulsion": [0,1.502],
        "rcut_in": 1.403,
        "dcut_in": 0.01
      },
      "PP": {
        "radbase": "ChebExpCos",
        "radparameters": [1.267],
        "rcut": 4.224,
        "dcut": 0.01,
        "core-repulsion": [0,1.267],
        "rcut_in": 1.1,
        "dcut_in": 0.01
      }
    },
    "rcutfac": [5.79,5.007,4.224],
    "ace_config": {
      "cutoff": 10.0,
      "deltaSplineBins": 0.001,
      "elements": ["In","P"],
      "embeddings": {
        "In": {
          "npot": "FinnisSinclair",
          "fs_parameters": [1,1],
          "ndensity": 1
        },
        "P": {
          "npot": "FinnisSinclair",
          "fs_parameters": [1,1],
          "ndensity": 1
        }
      },
      "bonds": {
        "InIn": {
          "radbase": "ChebExpCos",
          "radparameters": [1.737],
          "rcut": 5.79,
          "dcut": 0.01,
          "core-repulsion": [0,1.737],
          "rcut_in": 1.705,
          "dcut_in": 0.01
        },
        "PIn": {
          "radbase": "ChebExpCos",
          "radparameters": [1.502],
          "rcut": 5.007,
          "dcut": 0.01,
          "core-repulsion": [0,1.502],
          "rcut_in": 1.403,
          "dcut_in": 0.01
        },
        "PP": {
          "radbase": "ChebExpCos",
          "radparameters": [1.267],
          "rcut": 4.224,
          "dcut": 0.01,
          "core-repulsion": [0,1.267],
          "rcut_in": 1.1,
          "dcut_in": 0.01
        }
      },
      "functions": {
        "ALL": {
          "nmax_by_rank": [22,3,2,1],
          "lmin_by_rank": [0,0,1,1],
          "lmax_by_rank": [1,2,2,1]
        }
      }
    },
    "ctilde_basis": "<lammps_pyace.basis.ACECTildeBasisSet object at 0x3506bc030>",
    "ncoeff": 362,
,2] ls [0,0]","In P P ns [1,2] ls [1,1]","In P P ns [1,3] ls [0,0]","In P P ns [1,3] ls [1,1]","In P P ns [2,2] ls [0,0]","In P P ns [2,2] ls [1,1]","In P P ns [2,3] ls [0,0]","In P P ns [2,3] ls [1,1]","In P P ns [3,3] ls [0,0]","In P P ns [3,3] ls [1,1]","In In In In ns [1,1,1] ls [1,1,2]","In In In In ns [1,1,1] ls [1,2,1]","In In In In ns [1,1,1] ls [2,2,2]","In In In In ns [1,1,2] ls [1,1,2]","In In In In ns [1,1,2] ls [1,2,1]","In In In In ns [1,1,2] ls [2,1,1]","In In In In ns [1,1,2] ls [2,2,2]","In In In In ns [1,2,2] ls [1,1,2]","In In In In ns [1,2,2] ls [1,2,1]","In In In In ns [1,2,2] ls [2,1,1]","In In In In ns [1,2,2] ls [2,2,2]","In In In In ns [2,2,2] ls [1,1,2]","In In In In ns [2,2,2] ls [1,2,1]","In In In In ns [2,2,2] ls [2,2,2]","In In In P ns [1,1,1] ls [1,1,2]","In In In P ns [1,1,1] ls [1,2,1]","In In In P ns [1,1,1] ls [2,1,1]","In In In P ns [1,1,1] ls [2,2,2]","In In In P ns [1,1,2] ls [1,1,2]","In In In P ns [1,1,2] ls [1,2,1]","In In In P ns [1,1,2] ls [2,1,1]","In In In P ns [1,1,2] ls [2,2,2]","In In In P ns [1,2,1] ls [1,1,2]","In In In P ns [1,2,1] ls [1,2,1]","In In In P ns [1,2,1] ls [2,1,1]","In In In P ns [1,2,1] ls [2,2,2]","In In In P ns [1,2,2] ls [1,1,2]","In In In P ns [1,2,2] ls [1,2,1]","In In In P ns [1,2,2] ls [2,1,1]","In In In P ns [1,2,2] ls [2,2,2]","In In In P ns [2,2,1] ls [1,1,2]","In In In P ns [2,2,1] ls [1,2,1]","In In In P ns [2,2,1] ls [2,1,1]","In In In P ns [2,2,1] ls [2,2,2]","In In In P ns [2,2,2] ls [1,1,2]","In In In P ns [2,2,2] ls [1,2,1]","In In In P ns [2,2,2] ls [2,1,1]","In In In P ns [2,2,2] ls [2,2,2]","In In P P ns [1,1,1] ls [1,1,2]","In In P P ns [1,1,1] ls [1,2,1]","In In P P ns [1,1,1] ls [2,1,1]","In In P P ns [1,1,1] ls [2,2,2]","In In P P ns [1,1,2] ls [1,1,2]","In In P P ns [1,1,2] ls [1,2,1]","In In P P ns [1,1,2] ls [2,1,1]","In In P P ns [1,1,2] ls [2,2,2]","In In P P ns [1,2,2] ls [1,1,2]","In In P P ns [1,2,2] ls [1,2,1]","In In P P ns [1,2,2] ls [2,1,1]","In In P P ns [1,2,2] ls [2,2,2]","In In P P ns [2,1,1] ls [1,1,2]","In In P P ns [2,1,1] ls [1,2,1]","In In P P ns [2,1,1] ls [2,1,1]","In In P P ns [2,1,1] ls [2,2,2]","In In P P ns [2,1,2] ls [1,1,2]","In In P P ns [2,1,2] ls [1,2,1]","In In P P ns [2,1,2] ls [2,1,1]","In In P P ns [2,1,2] ls [2,2,2]","In In P P ns [2,2,2] ls [1,1,2]","In In P P ns [2,2,2] ls [1,2,1]","In In P P ns [2,2,2] ls [2,1,1]","In In P P ns [2,2,2] ls [2,2,2]","In P P P ns [1,1,1] ls [1,1,2]","In P P P ns [1,1,1] ls [1,2,1]","In P P P ns [1,1,1] ls [2,2,2]","In P P P ns [1,1,2] ls [1,1,2]","In P P P ns [1,1,2] ls [1,2,1]","In P P P ns [1,1,2] ls [2,1,1]","In P P P ns [1,1,2] ls [2,2,2]","In P P P ns [1,2,2] ls [1,1,2]","In P P P ns [1,2,2] ls [1,2,1]","In P P P ns [1,2,2] ls [2,1,1]","In P P P ns [1,2,2] ls [2,2,2]","In P P P ns [2,2,2] ls [1,1,2]","In P P P ns [2,2,2] ls [1,2,1]","In P P P ns [2,2,2] ls [2,2,2]","In In In In In ns [1,1,1,1] ls [1,1,1,1]","In In In In In ns [1,1,1,1] ls [1,1,2,2]","In In In In In ns [1,1,1,1] ls [2,2,2,2]","In In In In P ns [1,1,1,1] ls [1,1,1,1]","In In In In P ns [1,1,1,1] ls [1,1,2,2]","In In In In P ns [1,1,1,1] ls [1,2,2,1]","In In In In P ns [1,1,1,1] ls [2,1,2,1]","In In In In P ns [1,1,1,1] ls [2,2,1,1]","In In In In P ns [1,1,1,1] ls [2,2,2,2]","In In In P P ns [1,1,1,1] ls [1,1,1,1]","In In In P P ns [1,1,1,1] ls [1,1,2,2]","In In In P P ns [1,1,1,1] ls [2,2,2,2]","In In P P P ns [1,1,1,1] ls [1,1,1,1]","In In P P P ns [1,1,1,1] ls [1,1,2,2]","In In P P P ns [1,1,1,1] ls [2,1,1,2]","In In P P P ns [1,1,1,1] ls [2,2,2,2]","In P P P P ns [1,1,1,1] ls [1,1,1,1]","In P P P P ns [1,1,1,1] ls [1,1,2,2]","In P P P P ns [1,1,1,1] ls [2,2,2,2]","P In In ns [1,1] ls [0,0]","P In In ns [1,1] ls [1,1]","P In In ns [1,2] ls [0,0]","P In In ns [1,2] ls [1,1]","P In In ns [1,3] ls [0,0]","P In In ns [1,3] ls [1,1]","P In In ns [2,2] ls [0,0]","P In In ns [2,2] ls [1,1]","P In In ns [2,3] ls [0,0]","P In In ns [2,3] ls [1,1]","P In In ns [3,3] ls [0,0]","P In In ns [3,3] ls [1,1]","P In P ns [1,1] ls [0,0]","P In P ns [1,1] ls [1,1]","P In P ns [1,2] ls [0,0]","P In P ns [1,2] ls [1,1]","P In P ns [1,3] ls [0,0]","P In P ns [1,3] ls [1,1]","P In P ns [2,1] ls [0,0]","P In P ns [2,1] ls [1,1]","P In P ns [2,2] ls [0,0]","P In P ns [2,2] ls [1,1]","P In P ns [2,3] ls [0,0]","P In P ns [2,3] ls [1,1]","P In P ns [3,1] ls [0,0]","P In P ns [3,1] ls [1,1]","P In P ns [3,2] ls [0,0]","P In P ns [3,2] ls [1,1]","P In P ns [3,3] ls [0,0]","P In P ns [3,3] ls [1,1]","P P P ns [1,1] ls [0,0]","P P P ns [1,1] ls [1,1]","P P P ns [1,2] ls [0,0]","P P P ns [1,2] ls [1,1]","P P P ns [1,3] ls [0,0]","P P P ns [1,3] ls [1,1]","P P P ns [2,2] ls [0,0]","P P P ns [2,2] ls [1,1]","P P P ns [2,3] ls [0,0]","P P P ns [2,3] ls [1,1]","P P P ns [3,3] ls [0,0]","P P P ns [3,3] ls [1,1]","P In In In ns [1,1,1] ls [1,1,2]","P In In In ns [1,1,1] ls [1,2,1]","P In In In ns [1,1,1] ls [2,2,2]","P In In In ns [1,1,2] ls [1,1,2]","P In In In ns [1,1,2] ls [1,2,1]","P In In In ns [1,1,2] ls [2,1,1]","P In In In ns [1,1,2] ls [2,2,2]","P In In In ns [1,2,2] ls [1,1,2]","P In In In ns [1,2,2] ls [1,2,1]","P In In In ns [1,2,2] ls [2,1,1]","P In In In ns [1,2,2] ls [2,2,2]","P In In In ns [2,2,2] ls [1,1,2]","P In In In ns [2,2,2] ls [1,2,1]","P In In In ns [2,2,2] ls [2,2,2]","P In In P ns [1,1,1] ls [1,1,2]","P In In P ns [1,1,1] ls [1,2,1]","P In In P ns [1,1,1] ls [2,1,1]","P In In P ns [1,1,1] ls [2,2,2]","P In In P ns [1,1,2] ls [1,1,2]","P In In P ns [1,1,2] ls [1,2,1]","P In In P ns [1,1,2] ls [2,1,1]","P In In P ns [1,1,2] ls [2,2,2]","P In In P ns [1,2,1] ls [1,1,2]","P In In P ns [1,2,1] ls [1,2,1]","P In In P ns [1,2,1] ls [2,1,1]","P In In P ns [1,2,1] ls [2,2,2]","P In In P ns [1,2,2] ls [1,1,2]","P In In P ns [1,2,2] ls [1,2,1]","P In In P ns [1,2,2] ls [2,1,1]","P In In P ns [1,2,2] ls [2,2,2]","P In In P ns [2,2,1] ls [1,1,2]","P In In P ns [2,2,1] ls [1,2,1]","P In In P ns [2,2,1] ls [2,1,1]","P In In P ns [2,2,1] ls [2,2,2]","P In In P ns [2,2,2] ls [1,1,2]","P In In P ns [2,2,2] ls [1,2,1]","P In In P ns [2,2,2] ls [2,1,1]","P In In P ns [2,2,2] ls [2,2,2]","P In P P ns [1,1,1] ls [1,1,2]","P In P P ns [1,1,1] ls [1,2,1]","P In P P ns [1,1,1] ls [2,1,1]","P In P P ns [1,1,1] ls [2,2,2]","P In P P ns [1,1,2] ls [1,1,2]","P In P P ns [1,1,2] ls [1,2,1]","P In P P ns [1,1,2] ls [2,1,1]","P In P P ns [1,1,2] ls [2,2,2]","P In P P ns [1,2,2] ls [1,1,2]","P In P P ns [1,2,2] ls [1,2,1]","P In P P ns [1,2,2] ls [2,1,1]","P In P P ns [1,2,2] ls [2,2,2]","P In P P ns [2,1,1] ls [1,1,2]","P In P P ns [2,1,1] ls [1,2,1]","P In P P ns [2,1,1] ls [2,1,1]","P In P P ns [2,1,1] ls [2,2,2]","P In P P ns [2,1,2] ls [1,1,2]","P In P P ns [2,1,2] ls [1,2,1]","P In P P ns [2,1,2] ls [2,1,1]","P In P P ns [2,1,2] ls [2,2,2]","P In P P ns [2,2,2] ls [1,1,2]","P In P P ns [2,2,2] ls [1,2,1]","P In P P ns [2,2,2] ls [2,1,1]","P In P P ns [2,2,2] ls [2,2,2]","P P P P ns [1,1,1] ls [1,1,2]","P P P P ns [1,1,1] ls [1,2,1]","P P P P ns [1,1,1] ls [2,2,2]","P P P P ns [1,1,2] ls [1,1,2]","P P P P ns [1,1,2] ls [1,2,1]","P P P P ns [1,1,2] ls [2,1,1]","P P P P ns [1,1,2] ls [2,2,2]","P P P P ns [1,2,2] ls [1,1,2]","P P P P ns [1,2,2] ls [1,2,1]","P P P P ns [1,2,2] ls [2,1,1]","P P P P ns [1,2,2] ls [2,2,2]","P P P P ns [2,2,2] ls [1,1,2]","P P P P ns [2,2,2] ls [1,2,1]","P P P P ns [2,2,2] ls [2,2,2]","P In In In In ns [1,1,1,1] ls [1,1,1,1]","P In In In In ns [1,1,1,1] ls [1,1,2,2]","P In In In In ns [1,1,1,1] ls [2,2,2,2]","P In In In P ns [1,1,1,1] ls [1,1,1,1]","P In In In P ns [1,1,1,1] ls [1,1,2,2]","P In In In P ns [1,1,1,1] ls [1,2,2,1]","P In In In P ns [1,1,1,1] ls [2,1,2,1]","P In In In P ns [1,1,1,1] ls [2,2,1,1]","P In In In P ns [1,1,1,1] ls [2,2,2,2]","P In In P P ns [1,1,1,1] ls [1,1,1,1]","P In In P P ns [1,1,1,1] ls [1,1,2,2]","P In In P P ns [1,1,1,1] ls [2,2,2,2]","P In P P P ns [1,1,1,1] ls [1,1,1,1]","P In P P P ns [1,1,1,1] ls [1,1,2,2]","P In P P P ns [1,1,1,1] ls [2,1,1,2]","P In P P P ns [1,1,1,1] ls [2,2,2,2]","P P P P P ns [1,1,1,1] ls [1,1,1,1]","P P P P P ns [1,1,1,1] ls [1,1,2,2]","P P P P P ns [1,1,1,1] ls [2,2,2,2]"],
    "lambda_mask": "[ True  True  True  True  True False False False False False False False False False False False False False False False False False  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True False  True False  True False  True  True  True  True  True  True  True False  True  True  True False  True False  True  True  True False  True False  True  True  True False  True False  True False  True  True  True  True  True  True  True  True False False False False  True  True False  True  True  True False  True False False False False False False False  True  True  True  True  True  True False  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True False  True False  True False  True  True  True False  True  True  True False  True  True  True False  True  True  True  True  True  True False False  True  True False  True  True  True  True  True  True  True False False False False False False False False False False False False False False False False False False False  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True False False False False False False False False False False  True  True  True  True  True  True False  True False  True False  True  True  True False  True False  True False  True False False False  True  True  True  True  True  True  True  True  True  True  True  True False  True  True  True  True  True  True  True  True False False  True  True  True False False  True  True  True  True  True  True  True  True  True False False  True  True False  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True False  True  True  True False  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True False  True False  True  True  True False  True  True  True  True  True  True False False False False False False False False  True False False False False False  True False False  True False False]"
  },
  "CALCULATOR": {
    "name": "CALCULATOR",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["calculator","energy","per_atom_energy","force","stress","nonlinear","per_atom_scalar"],
    "calculator": "LAMMPSPYACE",
    "energy": 1,
    "per_atom_energy": 0,
    "per_atom_scalar": 0,
    "dee": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/detailed_energy_errors.dat",
    "force": 1,
    "dfe": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/detailed_force_errors.dat",
    "stress": 0,
    "dse": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/detailed_stress_errors.dat",
    "nonlinear": 0,
    "linear": true
  },
  "ESHIFT": {
    "name": "ESHIFT",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": null,
    "types": ["In","P"],
    "eshift": {
      "In": -1.65967588701534,
      "P": 4.38159549501534
    }
  },
  "SOLVER": {
    "name": "SOLVER",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["solver","normalweight","normratio","compute_testerrs","nsam","cov_nugget","mcmc_num","mcmc_gamma","mcmc_sigma","merr_mult","merr_method","merr_cfs"],
    "solver": "SLATE",
    "multinode": true,
    "normalweight": -12.0,
    "normratio": 0.5,
    "compute_testerrs": 1,
    "nsam": 0,
    "cov_nugget": 0.0,
    "mcmc_num": 10000,
    "mcmc_gamma": 0.01,
    "mcmc_sigma": 0.1,
    "merr_mult": 0,
    "merr_method": "abc",
    "merr_cfs": "all"
  },
  "SLATE": {
    "name": "SLATE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["method","alpha","max_iter","rtol","atol","alphabig","alphasmall","lambdabig","lambdasmall","directmethod","scap","scai","logcut","threshold_lambda"],
    "method": "ARD",
    "alpha": 1e-06,
    "max_iter": 10,
    "rtol": 0.001,
    "atol": 1e-06,
    "alphabig": 1e-12,
    "alphasmall": 1e-14,
    "lambdabig": 1e-06,
    "lambdasmall": 1e-06,
    "threshold_lambda": 3.16227766017,
    "directmethod": 0,
    "scap": 0.0001,
    "scai": 0.0001,
    "logcut": 0.3
  },
  "SCRAPER": {
    "name": "SCRAPER",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["scraper","filename","save_group_scrape","read_group_scrape","property_array","data_id","charge","composition","max_configs_per_rank"],
    "scraper": "JSON",
    "filename": "",
    "save_group_scrape": "None",
    "read_group_scrape": "None",
    "max_configs_per_rank": null,
    "data_id": "None",
    "charge": "None",
    "composition": "None",
    "properties": {
      "Stress": ["pressure","kB","Metal"],
      "Lattice": ["length","angstrom","Metal"],
      "Energy": ["energy","electronvolt","Metal"],
      "Positions": ["length","angstrom","Metal"],
      "Forces": ["force","electronvoltperangstrom","Metal"]
    }
  },
  "PATH": {
    "name": "PATH",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["dataPath","groupFile"],
    "infile_directory": "",
    "outfile_directory": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD",
    "datapath": "../InP_JPCA2020/JSON",
    "group_file": "grouplist.in"
  },
  "OUTFILE": {
    "name": "OUTFILE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["output_style","metrics","metrics_style","potential","validation"],
    "metric_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/InP_PYACE_SLATE_ARD.md",
    "potential_name": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/InP_PYACE_SLATE_ARD",
    "validation": "1",
    "adios2_stream": "<adios.file named stream:/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/InP_PYACE_SLATE_ARD.bp:mode:w and mode Mode.Write>",
    "metrics": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/InP_PYACE_SLATE_ARD.md",
    "potential": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/InP_PYACE_SLATE_ARD",
    "output_style": "PACE",
    "metrics_style": "MD"
  },
  "REFERENCE": {
    "name": "REFERENCE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["units","atom_style","pair_style","pair_coeff"],
    "units": "metal",
    "atom_style": "atomic",
    "lmp_pairdecl": ["pair_style zero 5.8","pair_coeff * *"]
  },
  "GROUPS": {
    "name": "GROUPS",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["group_sections","group_types","smartweights","random_sampling","random_seed","vasp_use_TOTEN","vasp_json_pathname","vasp_ignore_incomplete","vasp_ignore_jsons","vasp_unconverged_label","BOLTZ"],
    "group_sections": ["name","training_size","testing_size","eweight","fweight","vweight"],
    "group_types": ["<class 'str'>","<class 'float'>","<class 'float'>","<class 'float'>","<class 'float'>","<class 'float'>"],
    "smartweights": 1,
    "random_sampling": 0,
    "random_seed": 0.0,
    "vasp_use_TOTEN": 0,
    "vasp_json_pathname": "vJSON",
    "vasp_ignore_incomplete": 1,
    "vasp_ignore_jsons": 0,
    "vasp_unconverged_label": "UNCONVERGED",
    "boltz": 0.0,
    "group_table": {
      "aa": {
        "training_size": 19,
        "testing_size": 1,
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "aIn": {
        "training_size": 51,
        "testing_size": 3,
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "aP": {
        "training_size": 20,
        "testing_size": 1,
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "Bulk": {
        "training_size": 1,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 0.001,
        "vweight": 1e-12
      },
      "EOS": {
        "training_size": 255,
        "testing_size": 13,
        "eweight": 40.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "iIn": {
        "training_size": 39,
        "testing_size": 2,
        "eweight": 2.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "iP": {
        "training_size": 95,
        "testing_size": 5,
        "eweight": 2.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "s_aa": {
        "training_size": 17,
        "testing_size": 1,
        "eweight": 10.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "s_aIn": {
        "training_size": 115,
        "testing_size": 6,
        "eweight": 10.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "s_aP": {
        "training_size": 68,
        "testing_size": 4,
        "eweight": 10.0,
        "fweight": 200.0,
        "vweight": 1e-12
      },
      "Shear": {
        "training_size": 329,
        "testing_size": 17,
        "eweight": 22.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "s_iIn": {
        "training_size": 137,
        "testing_size": 7,
        "eweight": 10.0,
        "fweight": 300.0,
        "vweight": 1e-12
      },
      "s_iP": {
        "training_size": 320,
        "testing_size": 17,
        "eweight": 10.0,
        "fweight": 300.0,
        "vweight": 1e-12
      },
      "Strain": {
        "training_size": 155,
        "testing_size": 8,
        "eweight": 13.0,
        "fweight": 0.001,
        "vweight": 1e-12
      },
      "s_vIn": {
        "training_size": 16,
        "testing_size": 1,
        "eweight": 10.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "s_vP": {
        "training_size": 73,
        "testing_size": 4,
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "s_vv": {
        "training_size": 62,
        "testing_size": 3,
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 1e-12
      },
      "vP": {
        "training_size": 10,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 100.0,
        "vweight": 1e-12
      }
    }
  },
  "EXTRAS": {
    "name": "EXTRAS",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x104e31810>",
    "infile": "InP_PYACE_SLATE_ARD.in",
    "allowedkeys": ["multinode_testing","apply_transpose","only_test","dump_descriptors","dump_truth","dump_weights","dump_dataframe","dump_peratom","dump_perconfig","dump_configs","debug"],
    "multinode_testing": 0,
    "apply_transpose": 0,
    "only_test": 0,
    "dump_a": 0,
    "dump_b": 0,
    "dump_w": 0,
    "dump_dataframe": 0,
    "dump_peratom": 0,
    "dump_perconfig": 0,
    "dump_configs": 0,
    "debug": 0,
    "descriptor_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/Descriptors.npy",
    "truth_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/Truth-Ref.npy",
    "weights_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/Weights.npy",
    "dataframe_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/FitSNAP.df",
    "peratom_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/peratom.dat",
    "perconfig_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/perconfig.dat",
    "configs_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/InP_PYACE_SLATE_ARD/configs.pickle"
  }
}

# %% [markdown]
# ## SLURM

# %% [raw]
# n/a

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# ### Energy (meV/atom)
#
# **Unweighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1782</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.655039</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">27.053330</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.999262</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">93</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">15.577205</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">19.368058</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.999588</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_iIn</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">137</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">34.128130</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">34.591254</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">7</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">34.205072</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">34.639844</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_aIn</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">115</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.047048</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.049010</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.191135</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.191194</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aP</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">20</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">70.295894</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">158.458699</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.507712</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">23.530828</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">23.530828</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Strain</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">155</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">24.829571</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">31.732698</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.947042</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">8</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.551321</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">21.694136</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.845638</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_vv</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">62</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.117718</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.441062</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.001279</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.355855</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_aP</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">68</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.138333</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.345409</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">4</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.718493</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.851054</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;EOS</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">255</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.750382</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">21.289799</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.999382</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">13</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">12.094076</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.564279</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.998570</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aa</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">19</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.519804</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.519813</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.531233</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.531233</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_iP</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">320</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">12.499840</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.057172</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">17</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">12.592201</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.111358</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Shear</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">329</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">13.616170</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.494483</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.804603</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">17</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">10.577326</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.065489</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.894997</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;iP</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">95</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.037828</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.356237</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">5</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.729972</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">15.286610</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_vP</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">73</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">11.902577</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">11.906711</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">4</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">11.801583</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">11.802933</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aIn</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">51</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">9.671335</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">9.677905</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">9.875535</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">9.882258</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;iIn</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">39</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">8.201981</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">8.383181</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">2</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">8.610798</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">8.698405</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_aa</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">17</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">7.726892</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">7.727726</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">7.668211</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">7.668211</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_vIn</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">16</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">6.170957</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">6.172995</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">6.269755</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">6.269755</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Bulk</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">24.007270</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">24.007270</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;vP</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">10</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.552049</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.552049</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>
#
#
# **Weighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1782</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.979546</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">25.086799</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.999324</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">93</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">14.843764</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">18.953148</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.999546</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_iIn</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">137</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">34.128130</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">34.591254</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">7</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">34.205072</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">34.639844</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;s_aIn</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">115</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.047048</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.049010</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">6</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.191135</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">29.191194</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;aP</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">20</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">70.295894</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">158.458699</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.507712</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">23.530828</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">23.530828</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Strain</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">155</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">24.829571</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">31.732698</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.947042</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">8</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">17.551321</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">21.694136</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0