# %% [markdown]
# # SLATE ARD Validation Report
# /Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Ta_PYACE_SLATE_ARD

# %% [markdown]
# ## Configuration

# %%
import json

# Configuration from FitSNAP run
config = {
  "PYACE": {
    "name": "PYACE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": null,
    "elements": ["Ta"],
    "numtypes": 1,
    "types": ["Ta"],
    "cutoff": 10.0,
    "delta_spline_bins": 0.001,
    "bikflag": 0,
    "bzeroflag": 0,
    "dgradflag": 0,
    "erefs": ["0.0"],
    "type_mapping": {
      "Ta": 1
    },
    "embeddings": {
      "Ta": {
        "npot": "FinnisSinclair",
        "fs_parameters": [1,1],
        "ndensity": 1
      }
    },
    "functions": {
      "ALL": {
        "nmax_by_rank": [22,5,3,1],
        "lmin_by_rank": [0,0,1,1],
        "lmax_by_rank": [0,5,2,1]
      }
    },
    "bonds": {
      "ALL": {
        "radbase": "ChebExpCos",
        "radparameters": [1.275],
        "dcut": 0.01,
        "rcut": 4.25,
        "core-repulsion": [0,1.275],
        "rcut_in": 1.2,
        "dcut_in": 0.01
      }
    },
    "rcutfac": [4.25],
    "ace_config": {
      "cutoff": 10.0,
      "deltaSplineBins": 0.001,
      "elements": ["Ta"],
      "embeddings": {
        "Ta": {
          "npot": "FinnisSinclair",
          "fs_parameters": [1,1],
          "ndensity": 1
        }
      },
      "bonds": {
        "ALL": {
          "radbase": "ChebExpCos",
          "radparameters": [1.275],
          "dcut": 0.01,
          "rcut": 4.25,
          "core-repulsion": [0,1.275],
          "rcut_in": 1.2,
          "dcut_in": 0.01
        }
      },
      "functions": {
        "ALL": {
          "nmax_by_rank": [22,5,3,1],
          "lmin_by_rank": [0,0,1,1],
          "lmax_by_rank": [0,5,2,1]
        }
      }
    },
    "ctilde_basis": "<lammps_pyace.basis.ACECTildeBasisSet object at 0x3703660b0>",
    "ncoeff": 98,
    "blist": ["Ta [0]","Ta Ta ns [1] ls [0]","Ta Ta ns [2] ls [0]","Ta Ta ns [3] ls [0]","Ta Ta ns [4] ls [0]","Ta Ta ns [5] ls [0]","Ta Ta ns [6] ls [0]","Ta Ta ns [7] ls [0]","Ta Ta ns [8] ls [0]","Ta Ta ns [9] ls [0]","Ta Ta ns [10] ls [0]","Ta Ta ns [11] ls [0]","Ta Ta ns [12] ls [0]","Ta Ta ns [13] ls [0]","Ta Ta ns [14] ls [0]","Ta Ta ns [15] ls [0]","Ta Ta ns [16] ls [0]","Ta Ta ns [17] ls [0]","Ta Ta ns [18] ls [0]","Ta Ta ns [19] ls [0]","Ta Ta ns [20] ls [0]","Ta Ta ns [21] ls [0]","Ta Ta ns [22] ls [0]","Ta Ta Ta ns [1,1] ls [0,0]","Ta Ta Ta ns [1,1] ls [1,1]","Ta Ta Ta ns [1,2] ls [0,0]","Ta Ta Ta ns [1,2] ls [1,1]","Ta Ta Ta ns [1,3] ls [0,0]","Ta Ta Ta ns [1,3] ls [1,1]","Ta
ns [2,2,3] ls [1,2,1]","Ta Ta Ta Ta ns [2,2,3] ls [2,1,1]","Ta Ta Ta Ta ns [2,2,3] ls [2,2,2]","Ta Ta Ta Ta ns [2,3,3] ls [1,1,2]","Ta Ta Ta Ta ns [2,3,3] ls [1,2,1]","Ta Ta Ta Ta ns [2,3,3] ls [2,1,1]","Ta Ta Ta Ta ns [2,3,3] ls [2,2,2]","Ta Ta Ta Ta ns [3,3,3] ls [1,1,2]","Ta Ta Ta Ta ns [3,3,3] ls [1,2,1]","Ta Ta Ta Ta ns [3,3,3] ls [2,2,2]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [1,1,1,1]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [1,1,1,3]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [1,1,2,2]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [1,1,3,3]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [1,2,2,3]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [1,3,3,3]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [2,2,2,2]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [2,2,3,3]","Ta Ta Ta Ta Ta ns [1,1,1,1] ls [3,3,3,3]"],
    "lambda_mask": "[ True  True  True  True  True  True  True  True  True False  True False  True  True False False False False  True False  True  True  True False  True  True  True  True  True  True False  True  True  True  True  True  True  True  True  True  True  True  True  True  True False  True False  True False  True False  True  True False  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True  True False False False False  True False False False False]"
  },
  "CALCULATOR": {
    "name": "CALCULATOR",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["calculator","energy","per_atom_energy","force","stress","nonlinear","per_atom_scalar"],
    "calculator": "LAMMPSPYACE",
    "energy": 1,
    "per_atom_energy": 0,
    "per_atom_scalar": 0,
    "dee": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/detailed_energy_errors.dat",
    "force": 1,
    "dfe": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/detailed_force_errors.dat",
    "stress": 0,
    "dse": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/detailed_stress_errors.dat",
    "nonlinear": 0,
    "linear": true
  },
  "ESHIFT": {
    "name": "ESHIFT",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": null,
    "types": ["Ta"],
    "eshift": {
      "Ta": 0.0
    }
  },
  "SOLVER": {
    "name": "SOLVER",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["solver","normalweight","normratio","compute_testerrs","nsam","cov_nugget","mcmc_num","mcmc_gamma","mcmc_sigma","merr_mult","merr_method","merr_cfs"],
    "solver": "SLATE",
    "multinode": true,
    "normalweight": -12.0,
    "normratio": 0.5,
    "compute_testerrs": 1,
    "nsam": 0,
    "cov_nugget": 0.0,
    "mcmc_num": 10000,
    "mcmc_gamma": 0.01,
    "mcmc_sigma": 0.1,
    "merr_mult": 0,
    "merr_method": "abc",
    "merr_cfs": "all"
  },
  "SLATE": {
    "name": "SLATE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["method","alpha","max_iter","rtol","atol","alphabig","alphasmall","lambdabig","lambdasmall","directmethod","scap","scai","logcut","threshold_lambda"],
    "method": "ARD",
    "alpha": 1e-06,
    "max_iter": 10,
    "rtol": 0.001,
    "atol": 1e-06,
    "alphabig": 1e-12,
    "alphasmall": 1e-14,
    "lambdabig": 1e-06,
    "lambdasmall": 1e-06,
    "threshold_lambda": 0.0,
    "directmethod": 0,
    "scap": 0.0001,
    "scai": 0.0001,
    "logcut": 0.3
  },
  "SCRAPER": {
    "name": "SCRAPER",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["scraper","filename","save_group_scrape","read_group_scrape","property_array","data_id","charge","composition","max_configs_per_rank"],
    "scraper": "JSON",
    "filename": "",
    "save_group_scrape": "None",
    "read_group_scrape": "None",
    "max_configs_per_rank": null,
    "data_id": "None",
    "charge": "None",
    "composition": "None",
    "properties": {
      "Stress": ["pressure","bar","Metal"],
      "Lattice": ["length","angstrom","Metal"],
      "Energy": ["energy","electronvolt","Metal"],
      "Positions": ["length","angstrom","Metal"],
      "Forces": ["force","electronvoltperangstrom","Metal"]
    }
  },
  "PATH": {
    "name": "PATH",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["dataPath","groupFile"],
    "infile_directory": "",
    "outfile_directory": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD",
    "datapath": "../Ta_Linear_JCP2014/JSON",
    "group_file": "grouplist.in"
  },
  "OUTFILE": {
    "name": "OUTFILE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["output_style","metrics","metrics_style","potential","validation"],
    "metric_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Ta_PYACE_SLATE_ARD.md",
    "potential_name": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Ta_PYACE_SLATE_ARD",
    "validation": "1",
    "adios2_stream": "<adios.file named stream:/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Ta_PYACE_SLATE_ARD.bp:mode:w and mode Mode.Write>",
    "metrics": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Ta_PYACE_SLATE_ARD.md",
    "potential": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Ta_PYACE_SLATE_ARD",
    "output_style": "PACE",
    "metrics_style": "MD"
  },
  "REFERENCE": {
    "name": "REFERENCE",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["units","atom_style","pair_style","pair_coeff"],
    "units": "metal",
    "atom_style": "atomic",
    "lmp_pairdecl": ["pair_style hybrid/overlay zero 4.25","pair_coeff * * zero"]
  },
  "GROUPS": {
    "name": "GROUPS",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["group_sections","group_types","smartweights","random_sampling","random_seed","vasp_use_TOTEN","vasp_json_pathname","vasp_ignore_incomplete","vasp_ignore_jsons","vasp_unconverged_label","BOLTZ"],
    "group_sections": ["name","training_size","testing_size","eweight","fweight","vweight"],
    "group_types": ["<class 'str'>","<class 'float'>","<class 'float'>","<class 'float'>","<class 'float'>","<class 'float'>"],
    "smartweights": 1,
    "random_sampling": 0,
    "random_seed": 0.0,
    "vasp_use_TOTEN": 0,
    "vasp_json_pathname": "vJSON",
    "vasp_ignore_incomplete": 1,
    "vasp_ignore_jsons": 0,
    "vasp_unconverged_label": "UNCONVERGED",
    "boltz": 0.0,
    "group_table": {
      "Displaced_A15": {
        "training_size": 9,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 20.0,
        "vweight": 1e-08
      },
      "Displaced_BCC": {
        "training_size": 9,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 20.0,
        "vweight": 1e-08
      },
      "Displaced_FCC": {
        "training_size": 9,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 20.0,
        "vweight": 1e-08
      },
      "Elastic_BCC": {
        "training_size": 100,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 10.0,
        "vweight": 1e-08
      },
      "Elastic_FCC": {
        "training_size": 100,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 10.0,
        "vweight": 1e-08
      },
      "GSF_110": {
        "training_size": 22,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 10.0,
        "vweight": 1e-08
      },
      "GSF_112": {
        "training_size": 22,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 10.0,
        "vweight": 1e-08
      },
      "Liquid": {
        "training_size": 3,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 10.0,
        "vweight": 1e-08
      },
      "Surface": {
        "training_size": 7,
        "testing_size": 0,
        "eweight": 1.0,
        "fweight": 10.0,
        "vweight": 1e-08
      },
      "Volume_A15": {
        "training_size": 30,
        "testing_size": 0,
        "eweight": 1.5,
        "fweight": 15.0,
        "vweight": 1e-08
      },
      "Volume_BCC": {
        "training_size": 21,
        "testing_size": 0,
        "eweight": 1.5,
        "fweight": 15.0,
        "vweight": 1e-08
      },
      "Volume_FCC": {
        "training_size": 31,
        "testing_size": 0,
        "eweight": 1.5,
        "fweight": 15.0,
        "vweight": 1e-08
      }
    }
  },
  "EXTRAS": {
    "name": "EXTRAS",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["multinode_testing","apply_transpose","only_test","dump_descriptors","dump_truth","dump_weights","dump_dataframe","dump_peratom","dump_perconfig","dump_configs","debug"],
    "multinode_testing": 1,
    "apply_transpose": 0,
    "only_test": 0,
    "dump_a": 0,
    "dump_b": 0,
    "dump_w": 0,
    "dump_dataframe": 0,
    "dump_peratom": 0,
    "dump_perconfig": 0,
    "dump_configs": 0,
    "debug": 0,
    "descriptor_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Descriptors.npy",
    "truth_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Truth-Ref.npy",
    "weights_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/Weights.npy",
    "dataframe_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/FitSNAP.df",
    "peratom_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/peratom.dat",
    "perconfig_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/perconfig.dat",
    "configs_file": "/Users/mitch/github/FitSNAP-alphataubio/examples/Ta_PYACE_SLATE_ARD/configs.pickle"
  },
  "MEMORY": {
    "name": "MEMORY",
    "pt": "<fitsnap3lib.parallel_tools.ParallelTools object at 0x1054a16d0>",
    "infile": "Ta_PYACE_SLATE_ARD.in",
    "allowedkeys": ["memory","override"],
    "mem_bytes": 25769803776,
    "memory": 25769803776,
    "override": 0
  }
}

# %% [markdown]
# ## SLURM

# %% [raw]
# n/a

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# ### Energy (meV/atom)
#
# **Unweighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">363</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">87.903198</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">125.386557</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.998769</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_A15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">9</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.017196</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.028639</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">9</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">5.577205</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">7.194875</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.978350</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">9</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">144.771070</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">144.773334</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Elastic_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">100</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">2.512251</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">3.057236</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Elastic_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">100</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">143.061465</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">143.081324</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;GSF_110</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">22</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">41.973190</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">42.006825</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;GSF_112</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">22</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">50.253906</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">50.308313</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Liquid</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">5.269595</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">6.289356</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995256</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Surface</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">7</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">40.504223</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">42.512835</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.536636</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_A15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">30</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">135.781717</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">159.609026</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997565</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">21</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">107.675632</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">144.544910</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.999805</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">31</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">228.491156</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">263.499875</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997081</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>
#
#
# **Weighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">363</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">86.656508</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">128.270947</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.999210</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_A15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">9</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.017196</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">28.028639</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">9</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">5.577205</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">7.194875</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.978350</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">9</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">144.771070</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">144.773334</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Elastic_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">100</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">2.512251</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">3.057236</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Elastic_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">100</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">143.061465</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">143.081324</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;GSF_110</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">22</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">41.973190</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">42.006825</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;GSF_112</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">22</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">50.253906</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">50.308313</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Liquid</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">3</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">5.269595</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">6.289356</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.995256</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Surface</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">7</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">40.504223</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">42.512835</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.536636</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_A15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">30</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">135.781717</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">159.609026</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997565</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">21</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">107.675632</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">144.544910</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.999805</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">31</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">228.491156</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">263.499875</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.997081</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Force (meV/A)
#
# **Unweighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">12672</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">87.189641</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">155.974187</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.950433</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_A15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1728</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">109.088384</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">137.073620</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.953601</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1458</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">183.705085</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">231.125372</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.970173</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1296</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">120.244741</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">151.050219</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.910093</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Elastic_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">600</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.067603</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.093469</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.919100</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Elastic_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1200</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.113746</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.164547</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.834684</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;GSF_110</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1584</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">33.729896</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">59.715415</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.791850</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;GSF_112</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1980</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">64.158614</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">103.725362</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.698465</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Liquid</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">900</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">305.517144</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">385.643834</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.945256</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Surface</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">708</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">47.634202</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">102.029009</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.800211</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_A15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">720</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">4.657626</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.287910</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">126</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">3.76e-11</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">1.16e-10</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">372</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">3.48e-11</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">1.25e-10</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>
#
#
# **Weighted Metrics**
#
# <table style="border-collapse: collapse; table-layout: auto; width: 100%; font-size: 14px;">
#   <thead>
#     <tr style="border-top: 2px solid black; border-bottom: 2px solid black;">
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: left; width: 24%;">Group</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%; ">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: center; width: 5%;">N</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">MAE</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">RMSE (&darr;)</th>
#       <th style="padding: 6px 10px; white-space: nowrap; text-align: right; width: 11%;">R²</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding: 4px 12px;"></td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Training</td>
#       <td colspan="4" style="text-align: center; padding: 4px 12px; font-style: italic; border-bottom: 1px solid #999;">Validation</td>
#     </tr>
#     <tr style="font-weight: bold;">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;"><strong>ALL</strong></td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">12672</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">77.547846</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">148.173045</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.953062</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_A15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1728</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">109.088384</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">137.073620</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.953601</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1458</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">183.705085</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">231.125372</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.970173</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Displaced_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1296</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">120.244741</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">151.050219</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.910093</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Elastic_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">600</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.067603</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.093469</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.919100</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Elastic_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1200</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.113746</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.164547</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.834684</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;GSF_110</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1584</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">33.729896</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">59.715415</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.791850</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;GSF_112</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">1980</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">64.158614</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">103.725362</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.698465</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Liquid</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">900</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">305.517144</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">385.643834</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.945256</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Surface</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">708</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">42.889602</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">93.643205</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.821441</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_A15</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">720</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">4.657626</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">16.287910</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_BCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">126</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">3.76e-11</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">1.16e-10</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="">
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: left; overflow: hidden; text-overflow: ellipsis;">&nbsp;&nbsp;Volume_FCC</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">372</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">3.48e-11</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">1.25e-10</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">0.000000</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: center; border-left: 5px solid white;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#       <td style="padding: 3px 5px; font-family: monospace; white-space: nowrap; text-align: right;">-</td>
#     </tr>
#     <tr style="border-bottom: 2px solid black;">
#       <td colspan="9"></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Energy Scatterplot

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..." style="width:90%;height:auto;"></div>

# %% [markdown]
# ### Force Scatterplot

# %% [markdown]
# <div align="center"><img src="data:image/png;base64,..." style="width:90%;height:auto;"></div>

# %% [markdown]
# ## Lambda Heatmaps

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# <div align="center"><img src="data:image/svg+xml;base64,..."></div>

# %% [markdown]
# ## Gamma / Lambda Histograms (by iteration)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Gamma Heatmap" style="width:100%;height:auto;">
